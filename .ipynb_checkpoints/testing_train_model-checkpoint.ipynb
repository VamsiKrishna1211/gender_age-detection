# %%
import pandas as pd

# %%
df = pd.read_csv ("croped_filter_expanded_data.csv")

# %%
df["path"]
# Out:
# 0         ./Dataset-copy/imdb_faces/imdb_crop/65/nm09249...
# 1         ./Dataset-copy/imdb_faces/imdb_crop/04/nm00004...
# 2         ./Dataset-copy/imdb_faces/imdb_crop/23/nm00003...
# 3         ./Dataset-copy/imdb_faces/imdb_crop/40/nm03260...
# 4         ./Dataset-copy/imdb_faces/imdb_crop/54/nm00003...
#                                 ...
# 371220    ./Dataset-copy/imdb_faces/imdb_crop/18/nm00000...
# 371221    ./Dataset-copy/imdb_faces/imdb_crop/83/nm02201...
# 371222    ./Dataset-copy/imdb_faces/imdb_crop/12/nm09146...
# 371223    ./Dataset-copy/imdb_faces/imdb_crop/46/nm02210...
# 371224    ./Dataset-copy/imdb_faces/imdb_crop/26/nm01210...
# Name: path, Length: 371225, dtype: object

# %%
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread(df["path"][1])
img2 = cv2.imread(df["path"][20])

# %%
plt.subplot(1,2,1); plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2); plt.imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))

# %%
print(img1.shape, img2.shape)
# Out:
# (338, 338, 3) (147, 146, 3)

# %%
img1_x = cv2.resize(img1, (128, ))
img2_x = cv2.resize(img2, (64,64))

# %%
plt.subplot(1,2,1); plt.imshow(cv2.cvtColor(img1_x, cv2.COLOR_BGR2RGB))
plt.subplot(1,2,2); plt.imshow(cv2.cvtColor(img2_x, cv2.COLOR_BGR2RGB))

# %%
img1
# Out:
# array([[[21, 27, 34],
#         [21, 27, 34],
#         [21, 27, 34],
#         ...,
#         [12, 11, 13],
#         [ 9,  8, 10],
#         [ 9,  8, 10]],
#
#        [[21, 27, 34],
#         [21, 27, 34],
#         [21, 27, 34],
#         ...,
#         [11, 10, 12],
#         [ 9,  8, 10],
#         [ 9,  8, 10]],
#
#        [[22, 28, 33],
#         [22, 28, 33],
#         [22, 28, 33],
#         ...,
#         [10,  9, 11],
#         [ 9,  8, 10],
#         [ 9,  8, 10]],
#
#        ...,
#
#        [[16, 16, 16],
#         [16, 16, 16],
#         [16, 16, 16],
#         ...,
#         [21, 20, 22],
#         [22, 20, 20],
#         [22, 20, 20]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]],
#
#        [[17, 17, 17],
#         [17, 17, 17],
#         [17, 17, 17],
#         ...,
#         [21, 21, 21],
#         [21, 21, 21],
#         [21, 21, 21]]], dtype=uint8)

# %%
df_cut = df[0:100]

# %%
df_cut
# Out:
#                                                  path  out_ages  out_genders  \
# 0   ./Dataset-copy/imdb_faces/imdb_crop/65/nm09249...        20            0
# 1   ./Dataset-copy/imdb_faces/imdb_crop/04/nm00004...        72            0
# 2   ./Dataset-copy/imdb_faces/imdb_crop/23/nm00003...        79            1
# 3   ./Dataset-copy/imdb_faces/imdb_crop/40/nm03260...        42            1
# 4   ./Dataset-copy/imdb_faces/imdb_crop/54/nm00003...        35            1
# ..                                                ...       ...          ...
# 95  ./Dataset-copy/imdb_faces/imdb_crop/04/nm00004...        72            0
# 96  ./Dataset-copy/imdb_faces/imdb_crop/26/nm01586...        42            1
# 97  ./Dataset-copy/imdb_faces/imdb_crop/15/nm00013...        43            0
# 98  ./Dataset-copy/imdb_faces/imdb_crop/24/nm15016...        13            0
# 99  ./Dataset-copy/imdb_faces/imdb_crop/13/nm03695...        31            1
#
#     face_scores    x    y    w    h
# 0      5.305110   95   86  265  265
# 1      4.461523   91   54  186  186
# 2      2.683944  104  116  217  217
# 3      4.495562   85   54  159  159
# 4      4.179086  104   73  328  328
# ..          ...  ...  ...  ...  ...
# 95     3.456495   53   59  167  167
# 96     5.200933   62   38  127  127
# 97     4.482319   87   55  134  134
# 98     2.774829   89   60  136  136
# 99     4.276202   76   53  209  209
#
# [100 rows x 8 columns]
