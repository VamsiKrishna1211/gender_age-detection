# %%
import logging
 
import datetime
import pandas as pd
import os

from PIL import Image
import numpy as np
from numpy import save, load

import keras
from keras.optimizers import SGD, Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, \
    GlobalMaxPool2D, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, Lambda, Conv2D
from keras.applications.resnet50 import ResNet50
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from keras import backend as K
from keras.callbacks import TensorBoard

from tqdm import tqdm
from collections import Counter
# Out:
# Using TensorFlow backend.

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
def read_and_resize(filepath, input_shape=(256, 256)):
    im = Image.open((filepath)).convert('RGB')
    im = im.resize(input_shape)
    im_array = np.array(im, dtype="uint8")#[..., ::-1]
    return np.array(im_array / (np.max(im_array)+ 0.001), dtype="float32")

datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    brightness_range=[0.2,1.5],
    zoom_range=0.2)

def augment(im_array):
    im_array = datagen.random_transform(im_array)
    return im_array

# %%
def gen(df, batch_size=8, aug=False):
    df = df.sample(frac=1)

    dict_age = {'(0, 2)' : 0,
                '(3, 5)' : 1,
                '(6, 10)' : 2,
                '(11, 15)' : 3,
                '(16, 20)' : 4,
                '(21, 30)' : 5,
                '(31, 40)' : 6,
                '(41, 50)' : 7,
                '(51, 60)' : 8,
                '(61, 70)' : 9,
                '(71, 80)' : 10,
                 '(81, 90)' : 11,
                 '(91, 100)' : 12}

    while True:
        for i, batch in enumerate([df[i:i+batch_size] for i in range(0,df.shape[0],batch_size)]):
            if aug:
                images = np.array([augment(read_and_resize(file_path)) for file_path in batch.path.values])
            else:
                images = np.array([read_and_resize(file_path) for file_path in batch.path.values])


            #labels = np.array([dict_age[g] for g in batch.out_ages.values])
            labels = np.array(batch.out_ages.values)

            labels = labels[..., np.newaxis]

            yield images, labels

# %%
# def get_model(optimizer,n_classes=1):

#     base_model = ResNet50(weights="./resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5", include_top=False)

#     #for layer in base_model.layers:
#     #    layer.trainable = False

#     x = base_model.output
#     x = GlobalAveragePooling2D()(x)
#     x = Dropout(0.2)(x)
#     #x = Flatten()
#     x = Dense(1000, activation="relu")(x)
#     x = Dropout(0.2)(x)
#     x = Dense(750,activation="relu")(x)
#     x = Dense(350,activation="relu")(x)
#     x = Dense(100,activation="relu")(x)
#     x = Dropout(0.2)(x)
#     if n_classes == 1:
#         x = Dense(n_classes, activation="sigmoid")(x)
#     else:
#         x = Dense(n_classes, activation="softmax")(x)

#     base_model = Model(base_model.input, x, name="base_model")
#     if n_classes == 1:
#         base_model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=optimizer)
#     else:
#         base_model.compile(loss="sparse_categorical_crossentropy", metrics=['acc'], optimizer=optimizer)

#     return base_model

# %%
def get_model(optimizer,n_classes=1):
    model = keras.Sequential()
    model.add(Conv2D(filters=32, kernel_size=(5,5), input_shape=(256,256,3),padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
    model.add(Conv2D(filters=64, kernel_size=(5,5), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
    model.add(Conv2D(filters=128, kernel_size=(5,5), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
    model.add(Conv2D(filters=128, kernel_size=(5,5), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
    model.add(Conv2D(filters=64, kernel_size=(5,5), activation='relu', padding='same'))
    model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))
    model.add(GlobalAveragePooling2D())
    #model.add()
    #model.add(Dense(47150, activation = 'relu'))
    #model.add(Dense(47150/2, activation = 'relu'))
    #model.add(Dense(47150/4, activation = 'relu'))
    #model.add(Dense(47150/8, activation = 'relu'))
    #model.add(Dense(n_classes, activation = 'softmax'))
        
    if n_classes == 1:
        model.add(Dense(n_classes, activation="sigmoid"))#(x)
    else:
        model.add(Dense(n_classes, activation="softmax"))#(x)
    #base_model = Model(base_model.input, x, name="base_model")
    if n_classes == 1:
        model.compile(loss="binary_crossentropy", metrics=['acc'], optimizer=optimizer)
    else:
        model.compile(loss="sparse_categorical_crossentropy", metrics=['acc'], optimizer=optimizer)

    return model

# %%
if __name__ == "__main__":
    base_path = "./Dataset-copy/"

    dict_age = {'(0, 2)' : 0,
                '(3, 5)' : 1,
                '(6, 10)' : 2,
                '(11, 15)' : 3,
                '(16, 20)' : 4,
                '(21, 30)' : 5,
                '(31, 40)' : 6,
                '(41, 50)' : 7,
                '(51, 60)' : 8,
                '(61, 70)' : 9,
                '(71, 80)' : 10,
                 '(81, 90)' : 11,
                 '(91, 100)' : 12}

    bag = 3

    all_indexes = list(range(5))
    
    accuracies = []
    print("Reading train and test CSV files ")
    train_df = pd.read_csv("imdb_dataset_with_ages_not_age_range.csv")
    #test_df = pd.read_csv("test_gender_filtered_data_with_path.csv")
    tr_tr, tr_val = train_test_split(train_df, test_size=0.1,random_state = 100)
    tr_val['out_ages'].groupby
    print("Reading Done.")
    cnt_ave = 0
    predictions = 0
#     print("Extracting test labels and test images from files")
#     test_images = load("imdb_test_images.npy")
#     test_labels = load("imdb_test_labels.npy")
#     print("Extracting Done.")
    #tr_tr, tr_val = train_test_split(train_df, test_size=0.1,random_state = 100)
    file_path = "imdb_age_recog_weights.h5"
    
    print("Generating callback_list")
    
#     log_dir="./logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
#     tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)
    
    checkpoint = ModelCheckpoint(file_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

    #early = EarlyStopping(monitor="val_acc", mode="max", patience=5)

#     reduce_on_plateau = ReduceLROnPlateau(monitor="val_loss",
#                                           mode="min", 
#                                           factor=0.1,
#                                           #cooldown=0,
#                                           patience=3,
#                                           verbose=1,
#                                           min_lr=0.00001)

    callbacks_list = [checkpoint,
                      #reduce_on_plateau
                      #tensorboard_callback
                      #early
                     ]  # early
    
    print("Done Generating callbacklist.")
    print("generating Model")
    optimizer = Adam(lr=0.001)
    model = get_model( optimizer,n_classes=99)
    print("Done generating model")
    print("Running Fit_generator")
    model.fit_generator(gen(tr_tr,batch_size=8, aug=True), 
                        validation_data=gen(tr_val), 
                        epochs=200, 
                        verbose=1, 
                        #workers=4,
                        callbacks=callbacks_list,
                        steps_per_epoch=100,#int(10740.75), 
                        validation_steps=50
                        #validation_data=((test_images), test_labels)
                        #use_multiprocessing=True
                       )
    #model.save(file_path)
    print("Trained Model saved to disk")
# Out:
# Reading train and test CSV files
# Reading Done.
# Generating callback_list
# Done Generating callbacklist.
# generating Model
# Done generating model
# Running Fit_generator
# Epoch 1/200
# 100/100 [==============================] - 15s 146ms/step - loss: 4.7630 - acc: 0.0237 - val_loss: 4.4774 - val_acc: 0.0325
#
# Epoch 00001: val_acc improved from -inf to 0.03250, saving model to imdb_age_recog_weights.h5
# Epoch 2/200
# 100/100 [==============================] - 12s 120ms/step - loss: 4.1226 - acc: 0.0213 - val_loss: 4.2703 - val_acc: 0.0350
#
# Epoch 00002: val_acc improved from 0.03250 to 0.03500, saving model to imdb_age_recog_weights.h5
# Epoch 3/200
# 100/100 [==============================] - 12s 120ms/step - loss: 4.0985 - acc: 0.0312 - val_loss: 3.6648 - val_acc: 0.0325
#
# Epoch 00003: val_acc did not improve from 0.03500
# Epoch 4/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9791 - acc: 0.0338 - val_loss: 3.7410 - val_acc: 0.0350
#
# Epoch 00004: val_acc did not improve from 0.03500
# Epoch 5/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9734 - acc: 0.0388 - val_loss: 3.9884 - val_acc: 0.0300
#
# Epoch 00005: val_acc did not improve from 0.03500
# Epoch 6/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9464 - acc: 0.0362 - val_loss: 3.8906 - val_acc: 0.0425
#
# Epoch 00006: val_acc improved from 0.03500 to 0.04250, saving model to imdb_age_recog_weights.h5
# Epoch 7/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9595 - acc: 0.0463 - val_loss: 4.1463 - val_acc: 0.0175
#
# Epoch 00007: val_acc did not improve from 0.04250
# Epoch 8/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9741 - acc: 0.0338 - val_loss: 3.9052 - val_acc: 0.0325
#
# Epoch 00008: val_acc did not improve from 0.04250
# Epoch 9/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9954 - acc: 0.0312 - val_loss: 4.6487 - val_acc: 0.0300
#
# Epoch 00009: val_acc did not improve from 0.04250
# Epoch 10/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9736 - acc: 0.0338 - val_loss: 3.7199 - val_acc: 0.0200
#
# Epoch 00010: val_acc did not improve from 0.04250
# Epoch 11/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9736 - acc: 0.0437 - val_loss: 4.0761 - val_acc: 0.0275
#
# Epoch 00011: val_acc did not improve from 0.04250
# Epoch 12/200
# 100/100 [==============================] - 12s 121ms/step - loss: 4.0107 - acc: 0.0300 - val_loss: 3.5593 - val_acc: 0.0275
#
# Epoch 00012: val_acc did not improve from 0.04250
# Epoch 13/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9846 - acc: 0.0312 - val_loss: 3.9744 - val_acc: 0.0250
#
# Epoch 00013: val_acc did not improve from 0.04250
# Epoch 14/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9561 - acc: 0.0288 - val_loss: 3.7589 - val_acc: 0.0350
#
# Epoch 00014: val_acc did not improve from 0.04250
# Epoch 15/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9752 - acc: 0.0425 - val_loss: 4.2454 - val_acc: 0.0300
#
# Epoch 00015: val_acc did not improve from 0.04250
# Epoch 16/200
# 100/100 [==============================] - 13s 129ms/step - loss: 3.9305 - acc: 0.0250 - val_loss: 4.1239 - val_acc: 0.0225
#
# Epoch 00016: val_acc did not improve from 0.04250
# Epoch 17/200
# 100/100 [==============================] - 13s 128ms/step - loss: 3.9241 - acc: 0.0375 - val_loss: 4.1547 - val_acc: 0.0350
#
# Epoch 00017: val_acc did not improve from 0.04250
# Epoch 18/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9068 - acc: 0.0388 - val_loss: 3.6768 - val_acc: 0.0150
#
# Epoch 00018: val_acc did not improve from 0.04250
# Epoch 19/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9303 - acc: 0.0350 - val_loss: 4.0673 - val_acc: 0.0350
#
# Epoch 00019: val_acc did not improve from 0.04250
# Epoch 20/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9704 - acc: 0.0237 - val_loss: 4.5103 - val_acc: 0.0250
#
# Epoch 00020: val_acc did not improve from 0.04250
# Epoch 21/200
# 100/100 [==============================] - 12s 120ms/step - loss: 3.9418 - acc: 0.0288 - val_loss: 3.9601 - val_acc: 0.0400
#
# Epoch 00021: val_acc did not improve from 0.04250
# Epoch 22/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9630 - acc: 0.0338 - val_loss: 4.1296 - val_acc: 0.0400
#
# Epoch 00022: val_acc did not improve from 0.04250
# Epoch 23/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9446 - acc: 0.0362 - val_loss: 4.1431 - val_acc: 0.0275
#
# Epoch 00023: val_acc did not improve from 0.04250
# Epoch 24/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9638 - acc: 0.0275 - val_loss: 3.9476 - val_acc: 0.0375
#
# Epoch 00024: val_acc did not improve from 0.04250
# Epoch 25/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9707 - acc: 0.0463 - val_loss: 3.8380 - val_acc: 0.0400
#
# Epoch 00025: val_acc did not improve from 0.04250
# Epoch 26/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9308 - acc: 0.0288 - val_loss: 3.8761 - val_acc: 0.0400
#
# Epoch 00026: val_acc did not improve from 0.04250
# Epoch 27/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9296 - acc: 0.0388 - val_loss: 3.9594 - val_acc: 0.0250
#
# Epoch 00027: val_acc did not improve from 0.04250
# Epoch 28/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9093 - acc: 0.0538 - val_loss: 3.6963 - val_acc: 0.0250
#
# Epoch 00028: val_acc did not improve from 0.04250
# Epoch 29/200
# 100/100 [==============================] - 12s 119ms/step - loss: 3.9352 - acc: 0.0350 - val_loss: 3.6678 - val_acc: 0.0275
#
# Epoch 00029: val_acc did not improve from 0.04250
# Epoch 30/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9683 - acc: 0.0437 - val_loss: 3.8181 - val_acc: 0.0350
#
# Epoch 00030: val_acc did not improve from 0.04250
# Epoch 31/200
# 100/100 [==============================] - 13s 133ms/step - loss: 3.9792 - acc: 0.0312 - val_loss: 4.5065 - val_acc: 0.0400
#
# Epoch 00031: val_acc did not improve from 0.04250
# Epoch 32/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9577 - acc: 0.0275 - val_loss: 3.8968 - val_acc: 0.0250
#
# Epoch 00032: val_acc did not improve from 0.04250
# Epoch 33/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9304 - acc: 0.0275 - val_loss: 3.4699 - val_acc: 0.0275
#
# Epoch 00033: val_acc did not improve from 0.04250
# Epoch 34/200
# 100/100 [==============================] - 13s 127ms/step - loss: 3.9464 - acc: 0.0388 - val_loss: 3.9219 - val_acc: 0.0550
#
# Epoch 00034: val_acc improved from 0.04250 to 0.05500, saving model to imdb_age_recog_weights.h5
# Epoch 35/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9445 - acc: 0.0325 - val_loss: 3.7201 - val_acc: 0.0375
#
# Epoch 00035: val_acc did not improve from 0.05500
# Epoch 36/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.
200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9398 - acc: 0.0288 - val_loss: 3.4761 - val_acc: 0.0250
#
# Epoch 00117: val_acc did not improve from 0.05500
# Epoch 118/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9289 - acc: 0.0312 - val_loss: 4.9023 - val_acc: 0.0375
#
# Epoch 00118: val_acc did not improve from 0.05500
# Epoch 119/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9677 - acc: 0.0437 - val_loss: 3.9829 - val_acc: 0.0225
#
# Epoch 00119: val_acc did not improve from 0.05500
# Epoch 120/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9535 - acc: 0.0325 - val_loss: 3.5007 - val_acc: 0.0425
#
# Epoch 00120: val_acc did not improve from 0.05500
# Epoch 121/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9157 - acc: 0.0312 - val_loss: 3.6342 - val_acc: 0.0300
#
# Epoch 00121: val_acc did not improve from 0.05500
# Epoch 122/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9397 - acc: 0.0288 - val_loss: 3.5210 - val_acc: 0.0525
#
# Epoch 00122: val_acc did not improve from 0.05500
# Epoch 123/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9699 - acc: 0.0350 - val_loss: 4.2837 - val_acc: 0.0300
#
# Epoch 00123: val_acc did not improve from 0.05500
# Epoch 124/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9367 - acc: 0.0400 - val_loss: 3.8526 - val_acc: 0.0450
#
# Epoch 00124: val_acc did not improve from 0.05500
# Epoch 125/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9422 - acc: 0.0325 - val_loss: 3.8991 - val_acc: 0.0525
#
# Epoch 00125: val_acc did not improve from 0.05500
# Epoch 126/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9414 - acc: 0.0400 - val_loss: 3.6827 - val_acc: 0.0375
#
# Epoch 00126: val_acc did not improve from 0.05500
# Epoch 127/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9560 - acc: 0.0362 - val_loss: 3.6165 - val_acc: 0.0250
#
# Epoch 00127: val_acc did not improve from 0.05500
# Epoch 128/200
# 100/100 [==============================] - 13s 125ms/step - loss: 3.9888 - acc: 0.0250 - val_loss: 3.9692 - val_acc: 0.0375
#
# Epoch 00128: val_acc did not improve from 0.05500
# Epoch 129/200
# 100/100 [==============================] - 13s 126ms/step - loss: 3.9577 - acc: 0.0325 - val_loss: 3.6589 - val_acc: 0.0355
#
# Epoch 00129: val_acc did not improve from 0.05500
# Epoch 130/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9705 - acc: 0.0312 - val_loss: 4.0946 - val_acc: 0.0425
#
# Epoch 00130: val_acc did not improve from 0.05500
# Epoch 131/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9302 - acc: 0.0288 - val_loss: 3.6570 - val_acc: 0.0375
#
# Epoch 00131: val_acc did not improve from 0.05500
# Epoch 132/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9229 - acc: 0.0500 - val_loss: 4.0751 - val_acc: 0.0300
#
# Epoch 00132: val_acc did not improve from 0.05500
# Epoch 133/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9068 - acc: 0.0400 - val_loss: 4.0932 - val_acc: 0.0250
#
# Epoch 00133: val_acc did not improve from 0.05500
# Epoch 134/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9097 - acc: 0.0413 - val_loss: 3.7699 - val_acc: 0.0225
#
# Epoch 00134: val_acc did not improve from 0.05500
# Epoch 135/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9092 - acc: 0.0413 - val_loss: 4.0924 - val_acc: 0.0400
#
# Epoch 00135: val_acc did not improve from 0.05500
# Epoch 136/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.
200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9490 - acc: 0.0200 - val_loss: 3.8304 - val_acc: 0.0300
#
# Epoch 00156: val_acc did not improve from 0.06000
# Epoch 157/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9831 - acc: 0.0275 - val_loss: 4.3688 - val_acc: 0.0225
#
# Epoch 00157: val_acc did not improve from 0.06000
# Epoch 158/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9363 - acc: 0.0362 - val_loss: 3.7045 - val_acc: 0.0275
#
# Epoch 00158: val_acc did not improve from 0.06000
# Epoch 159/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9458 - acc: 0.0237 - val_loss: 3.8964 - val_acc: 0.0250
#
# Epoch 00159: val_acc did not improve from 0.06000
# Epoch 160/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9155 - acc: 0.0400 - val_loss: 3.8121 - val_acc: 0.0375
#
# Epoch 00160: val_acc did not improve from 0.06000
# Epoch 161/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9702 - acc: 0.0300 - val_loss: 4.1022 - val_acc: 0.0425
#
# Epoch 00161: val_acc did not improve from 0.06000
# Epoch 162/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9700 - acc: 0.0312 - val_loss: 3.9948 - val_acc: 0.0225
#
# Epoch 00162: val_acc did not improve from 0.06000
# Epoch 163/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9414 - acc: 0.0437 - val_loss: 4.1935 - val_acc: 0.0375
#
# Epoch 00163: val_acc did not improve from 0.06000
# Epoch 164/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9690 - acc: 0.0312 - val_loss: 3.8185 - val_acc: 0.0425
#
# Epoch 00164: val_acc did not improve from 0.06000
# Epoch 165/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9621 - acc: 0.0362 - val_loss: 4.2525 - val_acc: 0.0350
#
# Epoch 00165: val_acc did not improve from 0.06000
# Epoch 166/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9367 - acc: 0.0325 - val_loss: 4.1642 - val_acc: 0.0500
#
# Epoch 00166: val_acc did not improve from 0.06000
# Epoch 167/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9828 - acc: 0.0237 - val_loss: 4.1047 - val_acc: 0.0450
#
# Epoch 00167: val_acc did not improve from 0.06000
# Epoch 168/200
# 100/100 [==============================] - 12s 121ms/step - loss: 3.9488 - acc: 0.0425 - val_loss: 4.6478 - val_acc: 0.0200
#
# Epoch 00168: val_acc did not improve from 0.06000
# Epoch 169/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9652 - acc: 0.0388 - val_loss: 4.0135 - val_acc: 0.0375
#
# Epoch 00169: val_acc did not improve from 0.06000
# Epoch 170/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9610 - acc: 0.0362 - val_loss: 3.4827 - val_acc: 0.0400
#
# Epoch 00170: val_acc did not improve from 0.06000
# Epoch 171/200
# 100/100 [==============================] - 12s 124ms/step - loss: 3.9120 - acc: 0.0362 - val_loss: 4.0548 - val_acc: 0.0300
#
# Epoch 00171: val_acc did not improve from 0.06000
# Epoch 172/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9608 - acc: 0.0400 - val_loss: 3.8816 - val_acc: 0.0609
#
# Epoch 00172: val_acc improved from 0.06000 to 0.06091, saving model to imdb_age_recog_weights.h5
# Epoch 173/200
# 100/100 [==============================] - 13s 127ms/step - loss: 3.9322 - acc: 0.0275 - val_loss: 3.6696 - val_acc: 0.0300
#
# Epoch 00173: val_acc did not improve from 0.06091
# Epoch 174/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9324 - acc: 0.0400 - val_loss: 4.1197 - val_acc: 0.0350
#
# Epoch 00174: val_acc did not improve from 0.06091
# Epoch 175/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9728 - acc: 0.0388 - val_loss: 3.9605 - val_acc: 0.0425
#
# Epoch 00175: val_acc did not improve from 0.06091
# Epoch 176/200
# 100/100 [==============================] - 12s 122ms/step - loss: 4.0187 - acc: 0.0350 - val_loss: 4.0227 - val_acc: 0.0275
#
# Epoch 00176: val_acc did not improve from 0.06091
# Epoch 177/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9615 - acc: 0.0338 - val_loss: 4.0838 - val_acc: 0.0425
#
# Epoch 00177: val_acc did not improve from 0.06091
# Epoch 178/200
# 100/100 [==============================] - 12s 123ms/step - loss: 3.9663 - acc: 0.0275 - val_loss: 4.0667 - val_acc: 0.0350
#
# Epoch 00178: val_acc did not improve from 0.06091
# Epoch 179/200
# 100/100 [==============================] - 12s 122ms/step - loss: 3.9526 - acc: 0.0275 - val_loss: 3.8132 - val_acc: 0.0600
#
# Epoch 00179: val_acc did not improve from 0.06091
# Epoch 180/200
#  70/100 [====================>.........] - ETA: 3s - loss: 3.9324 - acc: 0.0357
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-ce99f52e0550> in <module>
#      72                         callbacks=callbacks_list,
#      73                         steps_per_epoch=100,#int(10740.75),
# ---> 74                         validation_steps=50
#      75                         #validation_data=((test_images), test_labels)
#      76                         #use_multiprocessing=True
#
# ~/ML/lib/python3.7/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/ML/lib/python3.7/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# ~/ML/lib/python3.7/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     183             batch_index = 0
#     184             while steps_done < steps_per_epoch:
# --> 185                 generator_output = next(output_generator)
#     186
#     187                 if not hasattr(generator_output, '__len__'):
#
# ~/ML/lib/python3.7/site-packages/keras/utils/data_utils.py in get(self)
#     709                 try:
#     710                     future = self.queue.get(block=True)
# --> 711                     inputs = future.get(timeout=30)
#     712                     self.queue.task_done()
#     713                 except mp.TimeoutError:
#
# /usr/local/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     649
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#     653             raise TimeoutError
#
# /usr/local/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     646
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#     650     def get(self, timeout=None):
#
# /usr/local/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# /usr/local/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
train_df = pd.read_csv("imdb_dataset.csv")
tr_tr, tr_val = train_test_split(train_df, test_size=0.1,random_state = 100)
tr_val, tr_test = train_test_split(tr_val,test_size=0.1,random_state = 100)
test_images = np.array([read_and_resize(file_path) for file_path in tr_test.path.values])
test_labels = np.array([file_path for file_path in tr_test.path.values])

# %%
save("imdb_test_images.npy",test_images)

# %%
test_labels = np.array([int(g == "m") for g in tr_test.out_ages.values])

# %%
save("imdb_test_labels.npy",test_images)

# %%
len(test_labels)

# %%
model = load_model("imdb_age_recog_weights.h5")

# %%
y_predict = model.predict(test_images)

# %%
index = 0
prob_max_class = max(y_predict[index])
age_class = np.where(y_predict[index] == prob_max_class)

# %%
age_class[0][0]

# %%
dict_age = {'(0, 2)' : 0,
                '(3, 5)' : 1,
                '(6, 10)' : 2,
                '(11, 15)' : 3,
                '(16, 20)' : 4,
                '(21, 30)' : 5,
                '(31, 40)' : 6,
                '(41, 50)' : 7,
                '(51, 60)' : 8,
                '(61, 70)' : 9,
                '(71, 80)' : 10,
                 '(81, 90)' : 11,
                 '(91, 100)' : 12}

# %%
dict_age[age_class[0][0]]
