# %%
from keras.utils import plot_model
from keras.models import load_model
import keras
# Out:
# Using TensorFlow backend.
# /home/vamsik1211/anaconda3/envs/intelpython/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/vamsik1211/anaconda3/envs/intelpython/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/vamsik1211/anaconda3/envs/intelpython/lib/python3.5/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
model = load_model('imdb_age_recog_weights.h5')
# Out:
# WARNING:tensorflow:From /home/vamsik1211/anaconda3/envs/intelpython/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/vamsik1211/anaconda3/envs/intelpython/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
plot_model(model, to_file='model.png',show_shapes=True, expand_nested=True,dpi=96)

# %%
keras.utils.print_summary(model, line_length=None, positions=None, print_fn=None)

# %%
model2 = load_model('baseline_age.h5')

# %%
plot_model(model2, to_file='model.png',show_shapes=True, expand_nested=True,dpi=96)

# %%
# dict_age = {'(0, 2)' : 0,
#                 '(3, 5)' : 1,
#                 '(6, 10)' : 2,
#                 '(11, 15)' : 3,
#                 '(16, 20)' : 4,
#                 '(21, 30)' : 5,
#                 '(31, 40)' : 6,
#                 '(41, 50)' : 7,
#                 '(51, 60)' : 8,
#                 '(61, 70)' : 9,
#                 '(71, 80)' : 10,
#                  '(81, 90)' : 11,
#                  '(91, 100)' : 12}

# %%
import pandas as pd

# %%
df = pd.read_csv("imdb_dataset.csv")

# %%
df_rank = df.groupby('out_ages')
df['out_ages'].unique()
# Out:
# array([ 5,  6,  7,  8,  4,  3,  9, 10,  2,  1, 11,  0, 12])

# %%
df_rank.size()
# Out:
# out_ages
# 0        87
# 1        94
# 2      1100
# 3      3709
# 4      9005
# 5     46835
# 6     55247
# 7     32463
# 8     14267
# 9      6313
# 10     2203
# 11      499
# 12       30
# dtype: int64
